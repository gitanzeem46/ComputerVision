# %%
import cv2
import numpy as np

# %%
img = cv2.imread('/content/sample_data/original.jpg',0)

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('/content/sample_data/original.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=508x371>

# %%
img = cv2.imread('/content/sample_data/original.jpg',0)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=508x371>

# %%
# Reload the image in color mode to ensure it has 3 dimensions
img = cv2.imread('/content/sample_data/original.jpg')

# check if the image was loaded successfully in color
# Access and modify the blue channel of the image
# Thi line is kept from your original problematic cell, although the error was on index 2

img[:,:,2] =0 # This was the line causing the IndexError in your traceback
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=508x371>
